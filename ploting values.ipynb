# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2023',periods=10),columns=list('ABCD'))

# %%
ds
# Out:
#                    A         B         C         D
# 2023-01-01  0.699232  0.341128  0.634734  0.563286
# 2023-01-02  0.880740  0.802135  0.354152  0.840766
# 2023-01-03  0.621005  0.379323  0.199541  0.477535
# 2023-01-04  0.492078  0.056471  0.961759  0.289372
# 2023-01-05  0.918807  0.957987  0.747774  0.086913
# 2023-01-06  0.787010  0.194053  0.205266  0.413073
# 2023-01-07  0.446116  0.830882  0.619105  0.328447
# 2023-01-08  0.992350  0.403355  0.911168  0.094433
# 2023-01-09  0.150390  0.899530  0.194791  0.336249
# 2023-01-10  0.340016  0.784118  0.697637  0.505726

# %%
ds.plot()
# Out:
# <AxesSubplot:>
